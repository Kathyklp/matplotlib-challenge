# %%
#Pymaceuticals Inc. Analysis

# %%
#dependencies and setup
import pandas as pd
import numpy as np
import sklearn as sk
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy as sc
# make sure to hit run

# %%
#Variable Tracking as they appear in code
# df1 and df2 are raw source data
#combined_data is the combined dataframe of df1 + df2
#d4 is an array to hold the duplicate mice rows
#d3 is a copy of combined_data used in sorting
#d6 is used for the pivot table to determin the number of males adn females
#d5 is used for a backup copy of combined and cleaned data before data malipulation

# %%
#read in data files as raw data for practice
#https://www.youtube.com/watch?v=dUpyC40cF6Q

df1 = pd.read_csv(r"C:\Users\Owner\OneDrive\MSU Bootcamp\homework\05_challenge\starter_code\Starter_Code\Pymaceuticals\data\Mouse_metadata.csv")
df1
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)
# 0       k403     Ramicane    Male          21          16
# 1       s185    Capomulin  Female           3          17
# 2       x401    Capomulin  Female          16          15
# 3       m601    Capomulin    Male          22          17
# 4       g791     Ramicane    Male          11          16
# ..       ...          ...     ...         ...         ...
# 244     z314     Stelasyn  Female          21          28
# 245     z435     Propriva  Female          12          26
# 246     z581    Infubinol  Female          24          25
# 247     z795     Naftisol  Female          13          29
# 248     z969     Naftisol    Male           9          30
#
# [249 rows x 5 columns]

# %%
#read in files as raw data from computer for practice
df2 = pd.read_csv(r"C:\Users\Owner\OneDrive\MSU Bootcamp\homework\05_challenge\starter_code\Starter_Code\Pymaceuticals\data\Study_results.csv")
df2
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0        b128          0           45.000000                 0
# 1        f932          0           45.000000                 0
# 2        g107          0           45.000000                 0
# 3        a457          0           45.000000                 0
# 4        c819          0           45.000000                 0
# ...       ...        ...                 ...               ...
# 1888     r944         45           41.581521                 2
# 1889     u364         45           31.023923                 3
# 1890     p438         45           61.433892                 1
# 1891     x773         45           58.634971                 4
# 1892     b879         45           72.555239                 2
#
# [1893 rows x 4 columns]

# %%
#getting info about both dataframes 
##https://www.youtube.com/watch?v=dUpyC40cF6Q
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249 entries, 0 to 248
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Mouse ID      249 non-null    object
#  1   Drug Regimen  249 non-null    object
#  2   Sex           249 non-null    object
#  3   Age_months    249 non-null    int64
#  4   Weight (g)    249 non-null    int64
# dtypes: int64(2), object(3)
# memory usage: 9.9+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1893 entries, 0 to 1892
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Mouse ID            1893 non-null   object
#  1   Timepoint           1893 non-null   int64
#  2   Tumor Volume (mm3)  1893 non-null   float64
#  3   Metastatic Sites    1893 non-null   int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 59.3+ KB

# %%
df1.shape
# Out:
# (249, 5)

# %%
df2.shape
# Out:
# (1893, 4)

# %%
#Combining dataframes based on column 1 Mouse ID 
#the returned dataframe will be in alphabetical/ascending numerical order
combined_data=pd.merge(df1, df2, on="Mouse ID")

# %%
combined_data
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
combined_data.shape
# Out:
# (1893, 8)

# %%
# the number of mice
combined_data['Mouse ID'].nunique()
# Out:
# 249

# %%
# Optional: Get all the data for the duplicate mouse ID.
#check combined data for duplicates
#return duplicate rows
df4 = combined_data[combined_data.duplicated()]
df4
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909                45.0                 0

# %%
#mice 909 and g989 have duplicate values

# %%
#remove duplicates
combined_data.drop_duplicates()
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
combined_data.head(10)
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
# 5     k403     Ramicane  Male          21          16         25
# 6     k403     Ramicane  Male          21          16         30
# 7     k403     Ramicane  Male          21          16         35
# 8     k403     Ramicane  Male          21          16         40
# 9     k403     Ramicane  Male          21          16         45
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1
# ...

# %%
combined_data.tail(10)
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 1883     z969     Naftisol  Male           9          30          0
# 1884     z969     Naftisol  Male           9          30          5
# 1885     z969     Naftisol  Male           9          30         10
# 1886     z969     Naftisol  Male           9          30         15
# 1887     z969     Naftisol  Male           9          30         20
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 1883           45.000000                 0
# 1884           49.332999                 0
# 1885           52.656081                 1
# 1886           54.713005                 2
# ...

# %%
#make a copy of the combined dataframe to manipulate for more data newdf=df.copy()
#https://www.w3schools.com/python/pandas/ref_df_copy.asp
d3=combined_data.copy()
d3
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
#checking data info 
d3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1893 entries, 0 to 1892
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Mouse ID            1893 non-null   object
#  1   Drug Regimen        1893 non-null   object
#  2   Sex                 1893 non-null   object
#  3   Age_months          1893 non-null   int64
#  4   Weight (g)          1893 non-null   int64
#  5   Timepoint           1893 non-null   int64
#  6   Tumor Volume (mm3)  1893 non-null   float64
#  7   Metastatic Sites    1893 non-null   int64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 133.1+ KB

# %%
# there are 248 different mice
# but there are 1893 rows of timepoints
# therefore not all mice have the same number of timepoints
# get summary statistics for combined file
d3.describe()
# Out:
#         Age_months   Weight (g)    Timepoint  Tumor Volume (mm3)  \
# count  1893.000000  1893.000000  1893.000000         1893.000000
# mean     12.814580    25.662441    19.572108           50.448381
# std       7.189592     3.921622    14.079460            8.894722
# min       1.000000    15.000000     0.000000           22.050126
# 25%       7.000000    25.000000     5.000000           45.000000
# 50%      13.000000    27.000000    20.000000           48.951474
# 75%      20.000000    29.000000    30.000000           56.292200
# max      24.000000    30.000000    45.000000           78.567014
#
#        Metastatic Sites
# count       1893.000000
# mean           1.021659
# std            1.137974
# min            0.000000
# 25%            0.000000
# 50%            1.000000
# 75%            2.000000
# max            4.000000

# %%
print(d3.dtypes)
# Out:
# Mouse ID               object
# Drug Regimen           object
# Sex                    object
# Age_months              int64
# Weight (g)              int64
# Timepoint               int64
# Tumor Volume (mm3)    float64
# Metastatic Sites        int64
# dtype: object

# %%
Summary Statistics
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# there are 10 different regimens
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary DataFrame.

# %%
#make a backup copy of data for manipulation in case file is accidently overwritten
#d5 is the combined and cleaned dataframe
d5=d3.copy()
d5
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
#sort by one column
d3.sort_values(by='Drug Regimen')
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 333      j119    Capomulin  Female           7          23         25
# 296      b742    Capomulin    Male           7          21         30
# 295      b742    Capomulin    Male           7          21         25
# 294      b742    Capomulin    Male           7          21         20
# 293      b742    Capomulin    Male           7          21         15
# ...       ...          ...     ...         ...         ...        ...
# 645      c264    Zoniferol  Female          11          27         35
# 646      c264    Zoniferol  Female          11          27         40
# 647      c264    Zoniferol  Female          11          27         45
# 1249     n967    Zoniferol    Male          11          27         10
# 502      a401    Zoniferol  Female           8          25          5
#
#       Tumor Volume (mm3)  Metastatic Sites
# 333            42.417166                 1
# ...

# %%
#sort by gender
d3.sort_values(by='Sex')
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 946      i386    Infubinol  Female          23          29         25
# 708      c766      Placebo  Female          13          26          5
# 709      c766      Placebo  Female          13          26         10
# 710      c766      Placebo  Female          13          26         15
# 711      c766      Placebo  Female          13          26         20
# ...       ...          ...     ...         ...         ...        ...
# 823      f278     Ketapril    Male          12          30          0
# 822      f234     Stelasyn    Male          14          28         35
# 821      f234     Stelasyn    Male          14          28         30
# 1252     o287     Ceftamin    Male           2          28          5
# 1892     z969     Naftisol    Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 946            56.687864                 3
# ...

# %%
#WRONG
#get count duplicates multiple columns using dataframe.pivot_table()
#d6 now holds the dataframe with the "Sex" column sorted
d6 = d3.pivot_table(index = ['Sex'], aggfunc ='size')
d6
# Out:
# Sex
# Female    935
# Male      958
# dtype: int64

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)

# Using the aggregation method, produce the same summary statistics in a single line

# %%
#Bar and Pie Charts
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.

# %%
#Bar and Pie Charts
# Generate a pie plot showing the distribution of female versus male mice using Pandas

# %%
#Bar and Pie Charts
# Generate a pie plot showing the distribution of female versus male mice using pyplot

# %%
Quartiles, OUtliers and Boxplots
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse


# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint

# %%
# Put treatments into a list for for loop (and later for plot labels)


# Create empty list to fill with tumor vol data (for plotting)


# Calculate the IQR and quantitatively determine if there are any potential outliers. 

    
    # Locate the rows which contain mice on each drug and get the tumor volumes

    
    # add subset 

    
    # Determine outliers using upper and lower bounds

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.

# %%
Line and Scatter Plots
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin

# %%
Line and scatter Plots
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen

# %%
Correlation and regression
# Calculate the correlation coefficient and a linear regression model 
# for mouse weight and average observed tumor volume for the entire Capomulin regimen

# %%
#the correlation between mouse weight and the average tumor volume is 0.84
